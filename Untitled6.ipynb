# %%
#Pandas Mini Project 
## Student Performance Analysis & AI/ML Data Preparation

import pandas as pd

student = {
    "Student_ID" : [101,102,103,104,105,106,107,108,109,110,111,112,113],
    "Name" : ["Raj ","Amit","Priya","Sneha","Rahul","Pooja","Karan","Neha","Akash","Komal","Vikas","Riya","Raj"],
    "Age" : [21,22,20,23,21,22,20,21,24,23,None,22,21],
    "Gender" : ["Male","Male","Female","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male"],
    "City" : ["Pune","Mumbai","Nashik","Pune","Mumbai","Pune","Nashik","Pune","Mumbai","Pune","Pune","Mumbai","Pune"],
    "Course" : ["Python","AI","Python","Data Science","AI","Python","Data Science","AI","Python","Data Science","Python","AI","Python"],
    "Attendance" : [90,80,95,88,75,98,82,91,85,96,90,None,90],
    "Marks" : [85,75,92,81,65,96,79,89,72,94,None,85,85],
    "Purchased" : ["Yes","No","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","Yes"]
}

#df = pd.DataFrame(student)
#print(df)

# #PART 1 : Load Dataset 

# df.to_csv("student_performance.csv", index=False)
# print("student_performance.csv created successfully!")

# PART 2 : Data Exploration 

# df.head()       #1.Display first 5 rows. 
# df.tail()       #2.Display last 5 rows.
# df.shape        #3.Display dataset shape. 
# df.columns      #4.Display all column names.
# df.dtypes       #5.Display data types. 
# df.info()       #6.Display dataset information. 
# df.describe()   #7.Display statistical summary

# PART 3 : Data Cleaning 

# df.isnull()                                             #1.Find missing values.
# df.isnull().sum()                                       #2.Count missing values. 

# avg_age = df["Age"].mean()                              #3.Fill missing values in Age using the average age.      
# df["Age"] = df["Age"].fillna(avg_age)
# print(df)

# avg_marks = df["Marks"].mean()                          #4.Fill missing values in Marks using the average marks.     
# df["Marks"] = df["Marks"].fillna(avg_marks)
# print(df)
 
# avg_att = df["Attendance"].mean()                       #5.Fill missing values in Attendance using the average attendance. 
# df["Attendance"] = df["Attendance"].fillna(avg_att)
# print(df)

# df.isnull().sum()                                         #6.Verify that no missing values exist. 

# PART 4 : Duplicate Records 

# df.duplicated()             #1.Find duplicate rows. 
# df.duplicated().sum()       #2.Count duplicate rows. 
# df.drop_duplicates()        #3.Remove duplicate rows. 
# print(df)                   #4.Display the cleaned dataset.

# PART 5 : Data Selection 

# df["Name"]                       # 1. Name column. 
# df["Marks"]                      # 2. Marks column. 
# df[["Name","Marks"]]             # 3. Name and Marks columns. 
# df[["Name", "City", "Course"]]   # 4. Name, City and Course columns.

# PART 6 : Data Filtering  

# df[df["Marks"]>80]                                         #1. Students with Marks greater than 80. 
# df[df["Marks"]<70]                                         #2. Students with Marks less than 70. 
# df[df["City"] == "Pune"]                                   #3. Students from Pune. 
# df[df["City"] == "Mumbai"]                                 #4. Students from Mumbai. 
# df.loc[df["Gender"] == "Femal", "Gender"] = "Female"              #Check whether the value actually changed
# df[df["Gender"] == "Female"]                               #5. Female students. 
# df[df["Gender"] == "Male"]                                 #6. Male students. 
# df[df["Course"] == "AI"]                                   #7. Students enrolled in AI course.
# df.loc[df["Course"] == "Pthon", "Course"] = "Python"              #Replace the spelling mistake
# df[df["Course"] == "Python"]                               #8. Students enrolled in Python course. 
# df[df["Attendance"]>90]                                    #9. Students whose Attendance is greater than 90. 
# df[(df["Marks"] >= 70) & (df["Marks"] <= 90)]              #10. Students whose Marks are between 70 and 90. 
# df[(df["Gender"] == "Male") & (df["City"] == "Pune")]      #11. Male students from Pune. 
# df[(df["Gender"] == "Female") & (df["Marks"] >= 85)]       #12. Female students with Marks greater than 85.

# PART 7 : Sorting 

# df.sort_values("Marks")                           #1. Marks (Ascending Order) 
# df.sort_values("Marks",ascending = False)         #2. Marks (Descending Order) 
# df.sort_values("Attendance",ascending = False)    #3. Attendance (Highest to Lowest)
# df.sort_values("Age")                             #4. Age (Lowest to Highest)

# # PART 8 : Unique Values 

# df["City"].unique()        #1.Unique Cities. 
# df["Course"].unique()      #2.Unique Courses. 
# df["Gender"].unique()      #3.Unique Gender values. 
# df["Purchased"].unique()   #4.Unique Purchased values. 

# # PART 9 : Value Counts 

# df["City"].value_counts()         # 1. Number of students in each City.
# df["Course"].value_counts()       # 2. Number of students in each Course. 
# df["Gender"].value_counts()       # 3. Number of Male and Female students. 
# df["Purchased"].value_counts()    # 4. Number of Purchased = Yes and No.

# # PART 10 : GroupBy Analysis 

# df.groupby("Course")["Marks"].mean()            # 1. Average Marks by Course.
# df.groupby("Course")["Attendance"].mean()       # 2. Average Attendance by Course. 
# df.groupby("Course")["Marks"].sum()             # 3. Total Marks by Course. 
# df.groupby("Course")["Marks"].max()             # 4. Maximum Marks by Course.
# df.groupby("Course")["Marks"].min()             # 5. Minimum Marks by Course. 
# df.groupby("Course")["Student_ID"].count()      # 6. Total Students by Course. 
# df.groupby("Gender")["Marks"].mean()            # 7. Average Marks by Gender.
# df.groupby("City")["Attendance"].mean()         # 8. Average Attendance by City.

# # PART 11 : Aggregation Functions 
# # Using GroupBy and agg(), display the following for each Course. 

# df.groupby("Course").agg({"Marks": "sum"})            #1.Sum of Marks.
# df.groupby("Course").agg({"Marks": "mean"})           #2.Average Marks.
# df.groupby("Course").agg({"Marks": "min"})            #3.Minimum Marks.
# df.groupby("Course").agg({"Marks": "max"})            #4.Maximum Marks. 
# df.groupby("Course").agg({"Student_ID": "count"})     #5.Total Students     

# # PART 12 : Correlation 

# df.corr(numeric_only=True)                           # 1. Find correlation between numerical columns. 
# corr = df.corr(numeric_only=True)                    # 2. Identify the highest positive correlation. 
# print(corr["Marks"].sort_values(ascending=False))
# corr = df.corr(numeric_only=True)                    # 3. Identify the lowest correlation. 
# print(corr["Marks"].sort_values())

# # PART 13 : Handling Categorical Data 

# df["Gender"] = df["Gender"].replace({"Male": 1, "Female": 0})       #1. Encode the Gender Column
# df["Purchased"] = df["Purchased"].replace({"Yes": 1, "No": 0})      #2. Encode the Purchased Column  
# print(df)                                                           #3. Display the Updated Dataset
# print(df[["Gender", "Purchased"]])                                 #Verify Encoding

# PART 14 : One-Hot Encoding 
# Apply One-Hot Encoding on: City, Course

# city_encoded = pd.get_dummies(df["City"])        #1. One-Hot Encoding on City
# print(city_encoded)
# course_encoded = pd.get_dummies(df["Course"])    #2. One-Hot Encoding on Course  
# print(course_encoded)

# PART 15 : Feature Selection 
# Create Features (X) using: • Age • Attendance • Marks • Gender 
# Create Target (y): • Purchased 

# X = df[["Age", "Attendance", "Marks", "Gender"]]
# print("Features (X):")
# print(X)

# y = df["Purchased"]
# print("\nTarget (y):")
# print(y)

# PART 16 : Save Dataset 
# Save the cleaned dataset as: 
# cleaned_student_performance.csv

df.to_csv("cleaned_student_performance.csv", index=False)
print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!
